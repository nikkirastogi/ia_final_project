# %% [markdown]
# ## API Call

# %%
import requests
import time

# Replace 'YOUR_API_KEY' with your actual TMDb API key
API_KEY = 'API_KEY'
BASE_URL = 'https://api.themoviedb.org/3'

def get_movie_details(movie_ids):
    details = []
    for movie_id in movie_ids:
        endpoint = f'/movie/{movie_id}'
        params = {
            'api_key': API_KEY
        }
        response = requests.get(BASE_URL + endpoint, params=params)
        if response.status_code == 200:
            details.append(response.json())
        else:
            print(f"Error fetching details for movie ID {movie_id}. Status code: {response.status_code}")
        time.sleep(0.1)  # Delay to avoid rate limits
    return details

def fetch_movie_ids(page_start, page_limit):
    all_movie_ids = []
    for page in range(page_start, page_start + page_limit):
        endpoint = '/movie/popular'
        params = {
            'api_key': API_KEY,
            'page': page
        }
        response = requests.get(BASE_URL + endpoint, params=params)
        if response.status_code == 200:
            movie_data = response.json()
            movie_ids = [movie['id'] for movie in movie_data['results']]
            all_movie_ids.extend(movie_ids)
        else:
            print(f"Error fetching movie IDs from page {page}. Status code: {response.status_code}")
        time.sleep(0.1)  # Delay to avoid rate limits
    return all_movie_ids

# Loop to fetch data in chunks
total_cycles = 6
pages_per_cycle = 100
all_movie_details = []

for cycle in range(total_cycles):
    page_start = 1 + cycle * pages_per_cycle
    print(f"Fetching cycle {cycle + 1}, starting at page {page_start}...")
    movie_ids = fetch_movie_ids(page_start, pages_per_cycle)
    movie_details = get_movie_details(movie_ids)
    all_movie_details.extend(movie_details)

# Example: Print details of the first movie
if all_movie_details:
    first_movie = all_movie_details[0]
    print("Title:", first_movie['title'])
    print("Overview:", first_movie['overview'])
    print("Release Date:", first_movie['release_date'])
# Out:
# Fetching cycle 1, starting at page 1...
# Fetching cycle 2, starting at page 101...
# Fetching cycle 3, starting at page 201...
# Fetching cycle 4, starting at page 301...
# Fetching cycle 5, starting at page 401...
# Fetching cycle 6, starting at page 501...
# Error fetching movie IDs from page 501. Status code: 400
# Error fetching movie IDs from page 502. Status code: 400
# Error fetching movie IDs from page 503. Status code: 400
# Error fetching movie IDs from page 504. Status code: 400
# Error fetching movie IDs from page 505. Status code: 400
# Error fetching movie IDs from page 506. Status code: 400
# Error fetching movie IDs from page 507. Status code: 400
# Error fetching movie IDs from page 508. Status code: 400
# Error fetching movie IDs from page 509. Status code: 400
# Error fetching movie IDs from page 510. Status code: 400
# Error fetching movie IDs from page 511. Status code: 400
# Error fetching movie IDs from page 512. Status code: 400
# Error fetching movie IDs from page 513. Status code: 400
# Error fetching movie IDs from page 514. Status code: 400
# Error fetching movie IDs from page 515. Status code: 400
# Error fetching movie IDs from page 516. Status code: 400
# Error fetching movie IDs from page 517. Status code: 400
# Error fetching movie IDs from page 518. Status code: 400
# Error fetching movie IDs from page 519. Status code: 400
# Error fetching movie IDs from page 520. Status code: 400
# Error fetching movie IDs from page 521. Status code: 400
# Error fetching movie IDs from page 522. Status code: 400
# Error fetching movie IDs from page 523. Status code: 400
# Error fetching movie IDs from page 524. Status code: 400
# Error fetching movie IDs from page 525. Status code: 400
# Error fetching movie IDs from page 526. Status code: 400
# Error fetching movie IDs from page 527. Status code: 400
# Error fetching movie IDs from page 528. Status code: 400
# Error fetching movie IDs from page 529. Status code: 400
# Error fetching movie IDs from page 530. Status code: 400
# Error fetching movie IDs from page 531. Status code: 400
# Error fetching movie IDs from page 532. Status code: 400
# Error fetching movie IDs from page 533. Status code: 400
# Error fetching movie IDs from page 534. Status code: 400
# Error fetching movie IDs from page 535. Status code: 400
# Error fetching movie IDs from page 536. Status code: 400
# Error fetching movie IDs from page 537. Status code: 400
# Error fetching movie IDs from page 538. Status code: 400
# Error fetching movie IDs from page 539. Status code: 400
# Error fetching movie IDs from page 540. Status code: 400
# Error fetching movie IDs from page 541. Status code: 400
# Error fetching movie IDs from page 542. Status code: 400
# Error fetching movie IDs from page 543. Status code: 400
# Error fetching movie IDs from page 544. Status code: 400
# Error fetching movie IDs from page 545. Status code: 400
# Error fetching movie IDs from page 546. Status code: 400
# Error fetching movie IDs from page 547. Status code: 400
# Error fetching movie IDs from page 548. Status code: 400
# Error fetching movie IDs from page 549. Status code: 400
# Error fetching movie IDs from page 550. Status code: 400
# Error fetching movie IDs from page 551. Status code: 400
# Error fetching movie IDs from page 552. Status code: 400
# Error fetching movie IDs from page 553. Status code: 400
# Error fetching movie IDs from page 554. Status code: 400
# Error fetching movie IDs from page 555. Status code: 400
# Error fetching movie IDs from page 556. Status code: 400
# Error fetching movie IDs from page 557. Status code: 400
# Error fetching movie IDs from page 558. Status code: 400
# Error fetching movie IDs from page 559. Status code: 400
# Error fetching movie IDs from page 560. Status code: 400
# Error fetching movie IDs from page 561. Status code: 400
# Error fetching movie IDs from page 562. Status code: 400
# Error fetching movie IDs from page 563. Status code: 400
# Error fetching movie IDs from page 564. Status code: 400
# Error fetching movie IDs from page 565. Status code: 400
# Error fetching movie IDs from page 566. Status code: 400
# Error fetching movie IDs from page 567. Status code: 400
# Error fetching movie IDs from page 568. Status code: 400
# Error fetching movie IDs from page 569. Status code: 400
# Error fetching movie IDs from page 570. Status code: 400
# Error fetching movie IDs from page 571. Status code: 400
# Error fetching movie IDs from page 572. Status code: 400
# Error fetching movie IDs from page 573. Status code: 400
# Error fetching movie IDs from page 574. Status code: 400
# Error fetching movie IDs from page 575. Status code: 400
# Error fetching movie IDs from page 576. Status code: 400
# Error fetching movie IDs from page 577. Status code: 400
# Error fetching movie IDs from page 578. Status code: 400
# Error fetching movie IDs from page 579. Status code: 400
# Error fetching movie IDs from page 580. Status code: 400
# Error fetching movie IDs from page 581. Status code: 400
# Error fetching movie IDs from page 582. Status code: 400
# Error fetching movie IDs from page 583. Status code: 400
# Error fetching movie IDs from page 584. Status code: 400
# Error fetching movie IDs from page 585. Status code: 400
# Error fetching movie IDs from page 586. Status code: 400
# Error fetching movie IDs from page 587. Status code: 400
# Error fetching movie IDs from page 588. Status code: 400
# Error fetching movie IDs from page 589. Status code: 400
# Error fetching movie IDs from page 590. Status code: 400
# Error fetching movie IDs from page 591. Status code: 400
# Error fetching movie IDs from page 592. Status code: 400
# Error fetching movie IDs from page 593. Status code: 400
# Error fetching movie IDs from page 594. Status code: 400
# Error fetching movie IDs from page 595. Status code: 400
# Error fetching movie IDs from page 596. Status code: 400
# Error fetching movie IDs from page 597. Status code: 400
# Error fetching movie IDs from page 598. Status code: 400
# Error fetching movie IDs from page 599. Status code: 400
# Error fetching movie IDs from page 600. Status code: 400
# Title: Godzilla x Kong: The New Empire
# Overview: Following their explosive showdown, Godzilla and Kong must reunite against a colossal undiscovered threat hidden within our world, challenging their very existence – and our own.
# Release Date: 2024-03-27

# %%
all_movie_details
# Out:
# [{'adult': False,
#   'backdrop_path': '/qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg',
#   'belongs_to_collection': {'id': 1280074,
#    'name': 'Kong Collection',
#    'poster_path': '/lhyEUeOihbKf7ll8RCIE5CHTie3.jpg',
#    'backdrop_path': None},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.godzillaxkongmovie.com',
#   'id': 823464,
#   'imdb_id': 'tt14539740',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Godzilla x Kong: The New Empire',
#   'overview': 'Following their explosive showdown, Godzilla and Kong must reunite against a colossal undiscovered threat hidden within our world, challenging their very existence – and our own.',
#   'popularity': 1818.259,
#   'poster_path': '/tMefBSflR6PGQLv7WvFPpKLZkyk.jpg',
#   'production_companies': [{'id': 923,
#     'logo_path': '/8M99Dkt23MjQMTTWukq4m5XsEuo.png',
#     'name': 'Legendary Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-03-27',
#   'revenue': 522503756,
#   'runtime': 115,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Rise together or fall alone.',
#   'title': 'Godzilla x Kong: The New Empire',
#   'video': False,
#   'vote_average': 6.513,
#   'vote_count': 915},
#  {'adult': False,
#   'backdrop_path': '/jnE1GA7cGEfv5DJBoU2t4bZHaP4.jpg',
#   'belongs_to_collection': {'id': 1102610,
#    'name': 'Ape vs. Collection',
#    'poster_path': '/zLqSnZUYW2y333PaSrR45fS1T0V.jpg',
#    'backdrop_path': None},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 1094844,
#   'imdb_id': 'tt26785742',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Ape vs. Mecha Ape',
#   'overview': 'Recognizing the destructive power of its captive giant Ape, the military makes its own battle-ready A.I., Mecha Ape. But its first practical test goes horribly wrong, leaving the military no choice but to release the imprisoned giant ape to stop the colossal robot before it destroys downtown Chicago.',
#   'popularity': 1639.584,
#   'poster_path': '/dJaIw8OgACelojyV6YuVsOhtTLO.jpg',
#   'production_companies': [{'id': 1311,
#     'logo_path': '/ic2bTizdzRLDVzAvN7MXdUg3WQV.png',
#     'name': 'The Asylum',
#     'origin_country': 'US'},
#    {'id': 152189,
#     'logo_path': None,
#     'name': 'The Global Asylum, LLC.',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2023-03-24',
#   'revenue': 0,
#   'runtime': 80,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'This s#it is bananas!',
#   'title': 'Ape vs. Mecha Ape',
#   'video': False,
#   'vote_average': 5.872,
#   'vote_count': 78},
#  {'adult': False,
#   'backdrop_path': '/xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg',
#   'belongs_to_collection': {'id': 726871,
#    'name': 'Dune Collection',
#    'poster_path': '/wcVafar6Efk3YgFvh8oZQ4yHL6H.jpg',
#    'backdrop_path': '/ygVSGv86R0BTOKJIb8RQ1sFxs4q.jpg'},
#   'budget': 190000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.dunemovie.com',
#   'id': 693134,
#   'imdb_id': 'tt15239678',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Dune: Part Two',
#   'overview': 'Follow the mythic journey of Paul Atreides as he unites with Chani and the Fremen while on a path of revenge against the conspirators who destroyed his family. Facing a choice between the love of his life and the fate of the known universe, Paul endeavors to prevent a terrible future only he can foresee.',
#   'popularity': 1390.639,
#   'poster_path': '/1pdfLvkbY9ohJlCjQH2CZjjYVvJ.jpg',
#   'production_companies': [{'id': 923,
#     'logo_path': '/8M99Dkt23MjQMTTWukq4m5XsEuo.png',
#     'name': 'Legendary Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-02-27',
#   'revenue': 704300257,
#   'runtime': 167,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Long live the fighters.',
#   'title': 'Dune: Part Two',
#   'video': False,
#   'vote_average': 8.235,
#   'vote_count': 3599},
#  {'adult': False,
#   'backdrop_path': '/4woSOUD0equAYzvwhWBHIJDCM88.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 1096197,
#   'imdb_id': 'tt16253418',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'No Way Up',
#   'overview': "Characters from different backgrounds are thrown together when the plane they're travelling on crashes into the Pacific Ocean. A nightmare fight for survival ensues with the air supply running out and dangers creeping in from all sides.",
#   'popularity': 1245.817,
#   'poster_path': '/hu40Uxp9WtpL34jv3zyWLb5zEVY.jpg',
#   'production_companies': [{'id': 19638,
#     'logo_path': '/6R3XtbihMWuDRFnlm4MkpxhmEKf.png',
#     'name': 'Altitude Film Entertainment',
#     'origin_country': 'GB'},
#    {'id': 290,
#     'logo_path': '/jrgCuaQsY9ouP5ILZf4Dq4ZOkIX.png',
#     'name': 'Ingenious Media',
#     'origin_country': 'GB'},
#    {'id': 177401,
#     'logo_path': '/qGH1GhknZ1P8xv84tDILE8D2Cev.png',
#     'name': 'Hyprr Films',
#     'origin_country': 'GB'},
#    {'id': 215092,
#     'logo_path': None,
#     'name': 'Sarma Films',
#     'origin_country': 'GB'},
#    {'id': 218231,
#     'logo_path': '/qI1nnORhDrF2V18KdjitkIOdgN.png',
#     'name': 'Dimension Studio',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2024-01-18',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Brace yourself.',
#   'title': 'No Way Up',
#   'video': False,
#   'vote_average': 6.329,
#   'vote_count': 559},
#  {'adult': False,
#   'backdrop_path': '/kYgQzzjNis5jJalYtIHgrom0gOx.jpg',
#   'belongs_to_collection': {'id': 77816,
#    'name': 'Kung Fu Panda Collection',
#    'poster_path': '/xoYc0RYKSc3xC4S9OpPZxKocKtj.jpg',
#    'backdrop_path': '/uDosHOFFWtF5YteBRygHALFqLw2.jpg'},
#   'budget': 85000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.dreamworks.com/movies/kung-fu-panda-4',
#   'id': 1011985,
#   'imdb_id': 'tt21692408',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Kung Fu Panda 4',
#   'overview': 'Po is gearing up to become the spiritual leader of his Valley of Peace, but also needs someone to take his place as Dragon Warrior. As such, he will train a new kung fu practitioner for the spot and will encounter a villain called the Chameleon who conjures villains from the past.',
#   'popularity': 1230.013,
#   'poster_path': '/kDp1vUBnMpe8ak4rjgl3cLELqjU.jpg',
#   'production_companies': [{'id': 521,
#     'logo_path': '/kP7t6RwGz2AvvTkvnI1uteEwHet.png',
#     'name': 'DreamWorks Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-03-02',
#   'revenue': 503540090,
#   'runtime': 94,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Kung Fu Panda 4',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 1476},
#  {'adult': False,
#   'backdrop_path': '/tpiqEVTLRz2Mq7eLq5DT8jSrp71.jpg',
#   'belongs_to_collection': {'id': 934765,
#    'name': 'Rebel Moon Collection',
#    'poster_path': '/17fiEIxD7ClGW33IdxpRb0mdXgF.jpg',
#    'backdrop_path': '/tCo96jmjKEMoWa5eCZNNss3MtMH.jpg'},
#   'budget': 83000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://www.netflix.com/title/81624666',
#   'id': 934632,
#   'imdb_id': 'tt23137904',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Rebel Moon - Part Two: The Scargiver',
#   'overview': 'The rebels gear up for battle against the ruthless forces of the Motherworld as unbreakable bonds are forged, heroes emerge — and legends are made.',
#   'popularity': 1187.439,
#   'poster_path': '/cxevDYdeFkiixRShbObdwAHBZry.jpg',
#   'production_companies': [{'id': 114152,
#     'logo_path': '/xYfrnGFXxrEy5x5OVThunxHYScK.png',
#     'name': 'The Stone Quarry',
#     'origin_country': 'US'},
#    {'id': 156880,
#     'logo_path': None,
#     'name': 'Grand Electric',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-04-19',
#   'revenue': 0,
#   'runtime': 123,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Rebel Moon - Part Two: The Scargiver',
#   'video': False,
#   'vote_average': 6.117,
#   'vote_count': 635},
#  {'adult': False,
#   'backdrop_path': '/5Eip60UDiPLASyKjmHPMruggTc4.jpg',
#   'belongs_to_collection': None,
#   'budget': 9000000,
#   'genres': [{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.immaculate.film',
#   'id': 1041613,
#   'imdb_id': 'tt23137390',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Immaculate',
#   'overview': 'An American nun embarks on a new journey when she joins a remote convent in the Italian countryside. However, her warm welcome quickly turns into a living nightmare when she discovers her new home harbours a sinister secret and unspeakable horrors.',
#   'popularity': 892.57,
#   'poster_path': '/fdZpvODTX5wwkD0ikZNaClE4AoW.jpg',
#   'production_companies': [{'id': 22146,
#     'logo_path': '/jPBtpMh0AUFqf9yfOJXer9d5Rei.png',
#     'name': 'Black Bear Pictures',
#     'origin_country': 'US'},
#    {'id': 184023,
#     'logo_path': '/fpMQBF9krWUG3nPN4qV6d1ibkFM.png',
#     'name': 'Fifty-Fifty Films',
#     'origin_country': 'US'},
#    {'id': 216431,
#     'logo_path': None,
#     'name': 'Middle Child Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-03-20',
#   'revenue': 21956543,
#   'runtime': 89,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}],
#   'status': 'Released',
#   'tagline': 'Not every intervention is divine.',
#   'title': 'Immaculate',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 367},
#  {'adult': False,
#   'backdrop_path': '/6a3aiSYNqABoV1Fq8n10LMOBxhH.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://578movie.com/',
#   'id': 821937,
#   'imdb_id': 'tt13899926',
#   'origin_country': ['VN'],
#   'original_language': 'vi',
#   'original_title': '578: Phát Đạn Của Kẻ Điên',
#   'overview': 'A container truck driver, Hùng, lives an idyllic life with his little daughter, An. The father and daughter become the closest companions in every journey with their orange container truck. Life goes on like that until An has to leave her father to go to school. One day, Hùng is informed that An is suffering from severe depression. Relying on his old skills in the past and finding out the truth, Hùng becomes enraged and painful to know that his little girl was kidnapped by a male stranger. Starting his lone and intense journey looking for and chasing after the unknown abuser, Hùng realizes that to hunt down that psychopath he has to counter the massive underground forces behind him.',
#   'popularity': 843.881,
#   'poster_path': '/8Nw5v7wPfa2FwbKyx61K2nIBcKa.jpg',
#   'production_companies': [{'id': 147411,
#     'logo_path': '/yRbWF2ElD7rJpw1R40mvrgMbv1R.png',
#     'name': 'Lotte Entertainment (Vietnam)',
#     'origin_country': 'VN'},
#    {'id': 176354,
#     'logo_path': '/eNWqZZhwGxgTqENgLcJUZPEEZzZ.png',
#     'name': 'Tuvan Pictures',
#     'origin_country': 'VN'}],
#   'production_countries': [{'iso_3166_1': 'VN', 'name': 'Vietnam'}],
#   'release_date': '2022-05-20',
#   'revenue': 0,
#   'runtime': 108,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Vietnamese', 'iso_639_1': 'vi', 'name': 'Tiếng Việt'}],
#   'status': 'Released',
#   'tagline': 'Pain is when you let him live',
#   'title': '578: Magnum',
#   'video': False,
#   'vote_average': 5.05,
#   'vote_count': 20},
#  {'adult': False,
#   'backdrop_path': '/qGJASuD3fs9ZBxuEZoxCLVidVq8.jpg',
#   'belongs_to_collection': {'id': 913258,
#    'name': 'The Three Musketeers Collection',
#    'poster_path': '/qKgZ5e83JjeAyJ2Y2okl0g9YSBH.jpg',
#    'backdrop_path': '/RfneAULQMXEEnnXm1E0f2BykrW.jpg'},
#   'budget': 39000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 845111,
#   'imdb_id': 'tt12672620',
#   'origin_country': ['FR'],
#   'original_language': 'fr',
#   'original_title': 'Les trois mousquetaires : Milady',
#   'overview': "D'Artagnan, on a quest to rescue the abducted Constance, runs into the mysterious Milady de Winter again. The tension between the Catholics and the Protestants finally escalates, as the king declares war — forcing the now four musketeers into battle. But as the war goes on, they are tested physically, mentally and emotionally.",
#   'popularity': 796.029,
#   'poster_path': '/rtosxP5sXuoRFPH4sVbMccLIPiV.jpg',
#   'production_companies': [{'id': 7981,
#     'logo_path': '/6Yv1gIAuGkHS5Vis4UjnqHhCPWV.png',
#     'name': 'Pathé',
#     'origin_country': 'FR'},
#    {'id': 20339,
#     'logo_path': '/zPj4RPXztwznZcKDef583wqKERy.png',
#     'name': 'Chapter 2',
#     'origin_country': 'FR'},
#    {'id': 123175,
#     'logo_path': '/sexBzUUok6HAuTc3cg8eRc84TKX.png',
#     'name': 'DeAPlaneta',
#     'origin_country': 'ES'},
#    {'id': 47,
#     'logo_path': '/i7Z9ot2o3N5Sa3HrF09kniFs2y8.png',
#     'name': 'Constantin Film',
#     'origin_country': 'DE'},
#    {'id': 19037,
#     'logo_path': '/tceh2aAORA5JxIZSLQ1GkzTBZDL.png',
#     'name': 'uMedia',
#     'origin_country': 'BE'},
#    {'id': 8676,
#     'logo_path': '/5u4GmXn4QMU39GQxGZoGfNtQ23r.png',
#     'name': 'uFilm',
#     'origin_country': 'BE'},
#    {'id': 11620,
#     'logo_path': '/f3hRdCaK1w9qH1Qs8nLd2L2bae1.png',
#     'name': 'OCS',
#     'origin_country': 'FR'},
#    {'id': 20346,
#     'logo_path': None,
#     'name': 'Région Bretagne',
#     'origin_country': 'FR'},
#    {'id': 310,
#     'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#     'name': 'CNC',
#     'origin_country': 'FR'},
#    {'id': 104,
#     'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png',
#     'name': 'Canal+',
#     'origin_country': 'FR'},
#    {'id': 11246,
#     'logo_path': '/4YZ5CQZkJa2FIKGtjLLoKhNOAIw.png',
#     'name': 'La Région Île-de-France',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'DE', 'name': 'Germany'},
#    {'iso_3166_1': 'ES', 'name': 'Spain'}],
#   'release_date': '2023-12-13',
#   'revenue': 20888270,
#   'runtime': 121,
#   'spoken_languages': [{'english_name': 'French',
#     'iso_639_1': 'fr',
#     'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'The adventure continues, chaos ensues...',
#   'title': 'The Three Musketeers: Milady',
#   'video': False,
#   'vote_average': 6.5,
#   'vote_count': 372},
#  {'adult': False,
#   'backdrop_path': '/v5XyXZe8FADw8iHupB4L7QOAwH9.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://www.thegarfield-movie.com/',
#   'id': 748783,
#   'imdb_id': 'tt5779228',
#   'origin_country': ['US', 'GB'],
#   'original_language': 'en',
#   'original_title': 'The Garfield Movie',
#   'overview': 'Garfield, the world-famous, Monday-hating, lasagna-loving indoor cat, is about to have a wild outdoor adventure! After an unexpected reunion with his long-lost father – scruffy street cat Vic – Garfield and his canine friend Odie are forced from their perfectly pampered life into joining Vic in a hilarious, high-stakes heist.',
#   'popularity': 757.742,
#   'poster_path': '/zK2sFxZcelHJRPVr242rxy5VK4T.jpg',
#   'production_companies': [{'id': 1088,
#     'logo_path': '/9WOE5AQUXbOtLU6GTwfjS8OMF0v.png',
#     'name': 'Alcon Entertainment',
#     'origin_country': 'US'},
#    {'id': 15357,
#     'logo_path': '/uvaRT02pY9U8qLH8a9WwwAroDqr.png',
#     'name': 'Prime Focus',
#     'origin_country': 'IN'},
#    {'id': 31922,
#     'logo_path': '/omWPoru2LNayUOBqjMBLP9KrFrP.png',
#     'name': 'DNEG Animation',
#     'origin_country': 'GB'},
#    {'id': 5,
#     'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#     'name': 'Columbia Pictures',
#     'origin_country': 'US'},
#    {'id': 4569,
#     'logo_path': '/gpc5vn0dBR4N5MKNGxiUxWD98rD.png',
#     'name': 'Paws, Inc.',
#     'origin_country': 'US'},
#    {'id': 69437,
#     'logo_path': None,
#     'name': 'One Cool Film Production',
#     'origin_country': 'HK'},
#    {'id': 144610,
#     'logo_path': '/9qyKQTuU8vIlnffXKTjHnO3VIxw.png',
#     'name': 'Wayfarer Studios',
#     'origin_country': 'US'},
#    {'id': 11341,
#     'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png',
#     'name': 'Stage 6 Films',
#     'origin_country': 'US'},
#    {'id': 129772,
#     'logo_path': None,
#     'name': 'Andrews McMeel Universal',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'HK', 'name': 'Hong Kong'},
#    {'iso_3166_1': 'IN', 'name': 'India'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2024-04-30',
#   'revenue': 0,
#   'runtime': 101,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Indoor cat. Outdoor adventure.',
#   'title': 'The Garfield Movie',
#   'video': False,
#   'vote_average': 7.265,
#   'vote_count': 17},
#  {'adult': False,
#   'backdrop_path': '/bWIIWhnaoWx3FTVXv6GkYDv3djL.jpg',
#   'belongs_to_collection': None,
#   'budget': 15000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://tickets.godzilla.com',
#   'id': 940721,
#   'imdb_id': 'tt23289160',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'original_title': 'ゴジラ-1.0',
#   'overview': 'Postwar Japan is at its lowest point when a new crisis emerges in the form of a giant monster, baptized in the horrific power of the atomic bomb.',
#   'popularity': 726.877,
#   'poster_path': '/hkxxMIGaiCTmrEArK7J56JTKUlB.jpg',
#   'production_companies': [{'id': 882,
#     'logo_path': '/iDw9Xxok1d9WAM2zFicI8p3khTH.png',
#     'name': 'TOHO',
#     'origin_country': 'JP'},
#    {'id': 182161,
#     'logo_path': '/wvG4lK0m76M6jK8WbWkXNecA7SP.png',
#     'name': 'TOHO Studios',
#     'origin_country': 'JP'},
#    {'id': 12386,
#     'logo_path': '/oxvw2Mrq3GcTxFc2mlT7E5tpek7.png',
#     'name': 'Robot Communications',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2023-11-03',
#   'revenue': 115857413,
#   'runtime': 125,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'Postwar Japan. From zero to minus.',
#   'title': 'Godzilla Minus One',
#   'video': False,
#   'vote_average': 7.9,
#   'vote_count': 639},
#  {'adult': False,
#   'backdrop_path': '/fypydCipcWDKDTTCoPucBsdGYXW.jpg',
#   'belongs_to_collection': {'id': 173710,
#    'name': 'Planet of the Apes (Reboot) Collection',
#    'poster_path': '/afGkMC4HF0YtXYNkyfCgTDLFe6m.jpg',
#    'backdrop_path': '/2ZkvqfOJUCINozB00wmYuGJQW81.jpg'},
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.20thcenturystudios.com/movies/kingdom-of-the-planet-of-the-apes',
#   'id': 653346,
#   'imdb_id': 'tt11389872',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Kingdom of the Planet of the Apes',
#   'overview': "Several generations in the future following Caesar's reign, apes are now the dominant species and live harmoniously while humans have been reduced to living in the shadows. As a new tyrannical ape leader builds his empire, one young ape undertakes a harrowing journey that will cause him to question all that he has known about the past and to make choices that will define a future for apes and humans alike.",
#   'popularity': 686.196,
#   'poster_path': '/gKkl37BQuKTanygYQG1pyYgLVgf.jpg',
#   'production_companies': [{'id': 127928,
#     'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#     'name': '20th Century Studios',
#     'origin_country': 'US'},
#    {'id': 133024,
#     'logo_path': None,
#     'name': 'Oddball Entertainment',
#     'origin_country': 'US'},
#    {'id': 89254,
#     'logo_path': None,
#     'name': 'Jason T. Reed Productions',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-05-08',
#   'revenue': 0,
#   'runtime': 145,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'No one can stop the reign.',
#   'title': 'Kingdom of the Planet of the Apes',
#   'video': False,
#   'vote_average': 6.636,
#   'vote_count': 11},
#  {'adult': False,
#   'backdrop_path': '/k0ucFBBgSDTXYU8fVHXJyjAuIIe.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 27, 'name': 'Horror'}],
#   'homepage': '',
#   'id': 1063879,
#   'imdb_id': 'tt26744289',
#   'origin_country': ['FR'],
#   'original_language': 'fr',
#   'original_title': 'Vermines',
#   'overview': 'Residents of a rundown French apartment building battle against an army of deadly, rapidly reproducing spiders.',
#   'popularity': 678.79,
#   'poster_path': '/dY98PkUAbIGUUg0FhXEcOkbzHIZ.jpg',
#   'production_companies': [{'id': 125339,
#     'logo_path': '/1qMAzaB915azuJioe5FtHJXFL9A.png',
#     'name': 'My Box Films',
#     'origin_country': 'FR'},
#    {'id': 171659,
#     'logo_path': '/ha1f2fPtUQpNi7AUo80ie6EapXm.png',
#     'name': 'Tandem',
#     'origin_country': 'FR'},
#    {'id': 102874,
#     'logo_path': '/3oHMY8bVdqo8c9KSQw1ehMc0o3V.png',
#     'name': 'Charades',
#     'origin_country': 'FR'},
#    {'id': 142877,
#     'logo_path': '/c0Qhy9uvdXfvAZQ9e8GnT5Nb75m.png',
#     'name': 'Shudder',
#     'origin_country': 'US'},
#    {'id': 22784,
#     'logo_path': '/y8G4y9Z8tP0NJ0pPKb19eHPlykH.png',
#     'name': 'WTFilms',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2023-12-27',
#   'revenue': 2110014,
#   'runtime': 106,
#   'spoken_languages': [{'english_name': 'French',
#     'iso_639_1': 'fr',
#     'name': 'Français'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Infested',
#   'video': False,
#   'vote_average': 7.123,
#   'vote_count': 150},
#  {'adult': False,
#   'backdrop_path': '/ilK1JRbMjo4sMJtNKLOKnqRf1RH.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 10752, 'name': 'War'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 36, 'name': 'History'}],
#   'homepage': '',
#   'id': 976906,
#   'imdb_id': 'tt13434866',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Spitfire Over Berlin',
#   'overview': 'August 1944. With the American Eighth Air Force poised to strike over Nazi Germany, British Intelligence learns that they could be flying into a deadly trap. With only hours to spare, Flight Lieutenant Edward Barnes must fly a life and death mission over Berlin in his unarmed Spitfire to obtain photographic evidence and save the lives of 1200 men.',
#   'popularity': 667.795,
#   'poster_path': '/xtPPOPTad1qopK6uDe3VlYUa22o.jpg',
#   'production_companies': [{'id': 95706,
#     'logo_path': '/6H2AkKh3Li9jvzfxSublaPiVPIY.png',
#     'name': 'Tin Hat Productions',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2022-05-13',
#   'revenue': 0,
#   'runtime': 80,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "One pilot's heroic mission to hell and back.",
#   'title': 'Spitfire Over Berlin',
#   'video': False,
#   'vote_average': 4.133,
#   'vote_count': 15},
#  {'adult': False,
#   'backdrop_path': '/vTlK3chwsEToSoQJYUcJaHlNhIf.jpg',
#   'belongs_to_collection': None,
#   'budget': 19000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.arthurtheking.movie/',
#   'id': 618588,
#   'imdb_id': 'tt10720352',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Arthur the King',
#   'overview': 'Over the course of ten days and 435 miles, an unbreakable bond is forged between pro adventure racer Michael Light and a scrappy street dog companion dubbed Arthur. As the team is pushed to their outer limits of endurance in the race, Arthur redefines what victory, loyalty and friendship truly mean.',
#   'popularity': 651.969,
#   'poster_path': '/gxVcBc4VM0kAg9wX4HVg6KJHG46.jpg',
#   'production_companies': [{'id': 24049,
#     'logo_path': '/zOHQ0A3PpNoLLeAxRZwSqNV3nPr.png',
#     'name': 'Sierra/Affinity',
#     'origin_country': 'US'},
#    {'id': 8147,
#     'logo_path': '/q6HOAdSNgCbeOqwoMVRc6REgbXF.png',
#     'name': 'Entertainment One',
#     'origin_country': 'CA'},
#    {'id': 100033,
#     'logo_path': '/74LDJbOFdya1ijNT11uh0mM5eg0.png',
#     'name': 'Tucker Tooley Entertainment',
#     'origin_country': 'US'},
#    {'id': 169668,
#     'logo_path': None,
#     'name': 'Municipal Pictures',
#     'origin_country': 'US'},
#    {'id': 11761,
#     'logo_path': None,
#     'name': 'Mark Canton Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2024-03-15',
#   'revenue': 31649885,
#   'runtime': 107,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'An unexpected encounter. An unlikely bond. An unforgettable adventure.',
#   'title': 'Arthur the King',
#   'video': False,
#   'vote_average': 6.886,
#   'vote_count': 92},
#  {'adult': False,
#   'backdrop_path': '/pwGmXVKUgKN13psUjlhC9zBcq1o.jpg',
#   'belongs_to_collection': None,
#   'budget': 80000000,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.madameweb.movie',
#   'id': 634492,
#   'imdb_id': 'tt11057302',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Madame Web',
#   'overview': 'Forced to confront revelations about her past, paramedic Cassandra Webb forges a relationship with three young women destined for powerful futures...if they can all survive a deadly present.',
#   'popularity': 636.241,
#   'poster_path': '/rULWuutDcN5NvtiZi4FRPzRYWSh.jpg',
#   'production_companies': [{'id': 5,
#     'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#     'name': 'Columbia Pictures',
#     'origin_country': 'US'},
#    {'id': 435,
#     'logo_path': '/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png',
#     'name': 'di Bonaventura Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-02-14',
#   'revenue': 100298817,
#   'runtime': 116,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Her web connects them all.',
#   'title': 'Madame Web',
#   'video': False,
#   'vote_average': 5.609,
#   'vote_count': 1201},
#  {'adult': False,
#   'backdrop_path': '/oe7mWkvYhK4PLRNAVSvonzyUXNy.jpg',
#   'belongs_to_collection': None,
#   'budget': 85000000,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.amazon.com/gp/video/detail/B0CH5YQPZQ',
#   'id': 359410,
#   'imdb_id': 'tt3359350',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Road House',
#   'overview': 'Ex-UFC fighter Dalton takes a job as a bouncer at a Florida Keys roadhouse, only to discover that this paradise is not all it seems.',
#   'popularity': 625.791,
#   'poster_path': '/bXi6IQiQDHD00JFio5ZSZOeRSBh.jpg',
#   'production_companies': [{'id': 21,
#     'logo_path': '/usUnaYV6hQnlVAXP6r4HwrlLFPG.png',
#     'name': 'Metro-Goldwyn-Mayer',
#     'origin_country': 'US'},
#    {'id': 1885,
#     'logo_path': '/xlvoOZr4s1PygosrwZyolIFe5xs.png',
#     'name': 'Silver Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-03-08',
#   'revenue': 0,
#   'runtime': 121,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Take it outside.',
#   'title': 'Road House',
#   'video': False,
#   'vote_average': 7.016,
#   'vote_count': 1650},
#  {'adult': False,
#   'backdrop_path': '/nb3xI8XI3w4pMVZ38VijbsyBqP4.jpg',
#   'belongs_to_collection': None,
#   'budget': 100000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#   'homepage': 'http://www.oppenheimermovie.com',
#   'id': 872585,
#   'imdb_id': 'tt15398776',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Oppenheimer',
#   'overview': "The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.",
#   'popularity': 616.637,
#   'poster_path': '/8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg',
#   'production_companies': [{'id': 9996,
#     'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png',
#     'name': 'Syncopy',
#     'origin_country': 'GB'},
#    {'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 507,
#     'logo_path': '/aRmHe6GWxYMRCQljF75rn2B9Gv8.png',
#     'name': 'Atlas Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2023-07-19',
#   'revenue': 952000000,
#   'runtime': 181,
#   'spoken_languages': [{'english_name': 'Dutch',
#     'iso_639_1': 'nl',
#     'name': 'Nederlands'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The world forever changes.',
#   'title': 'Oppenheimer',
#   'video': False,
#   'vote_average': 8.111,
#   'vote_count': 7870},
#  {'adult': False,
#   'backdrop_path': '/2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg',
#   'belongs_to_collection': None,
#   'budget': 72000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://www.migration.movie',
#   'id': 940551,
#   'imdb_id': 'tt6495056',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Migration',
#   'overview': 'After a migrating duck family alights on their pond with thrilling tales of far-flung places, the Mallard family embarks on a family road trip, from New England, to New York City, to tropical Jamaica.',
#   'popularity': 607.748,
#   'poster_path': '/ldfCF9RhR40mppkzmftxapaHeTo.jpg',
#   'production_companies': [{'id': 6704,
#     'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png',
#     'name': 'Illumination',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2023-12-06',
#   'revenue': 297404638,
#   'runtime': 83,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Odd ducks welcome.',
#   'title': 'Migration',
#   'video': False,
#   'vote_average': 7.49,
#   'vote_count': 1275},
#  {'adult': False,
#   'backdrop_path': '/keVfqCMKmJ55nHzmqR2Q5K7LwJt.jpg',
#   'belongs_to_collection': None,
#   'budget': 30069500,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 10752, 'name': 'War'}],
#   'homepage': '',
#   'id': 784651,
#   'imdb_id': 'tt13818368',
#   'origin_country': ['IN'],
#   'original_language': 'hi',
#   'original_title': 'फाइटर',
#   'overview': 'Top IAF aviators come together in the face of imminent danger, to form Air Dragons. Fighter unfolds their camaraderie, brotherhood and battles, internal and external.',
#   'popularity': 605.327,
#   'poster_path': '/zDZowwb9GZGEctAu2PCpjiPQAMM.jpg',
#   'production_companies': [{'id': 147147,
#     'logo_path': None,
#     'name': 'Marflix Pictures',
#     'origin_country': 'IN'},
#    {'id': 6808,
#     'logo_path': '/xa1Yz7B5eRC2F9oHA6mDn8NE6ci.png',
#     'name': 'Viacom18 Studios',
#     'origin_country': 'IN'},
#    {'id': 15357,
#     'logo_path': '/uvaRT02pY9U8qLH8a9WwwAroDqr.png',
#     'name': 'Prime Focus',
#     'origin_country': 'IN'}],
#   'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#   'release_date': '2024-01-24',
#   'revenue': 43160558,
#   'runtime': 167,
#   'spoken_languages': [{'english_name': 'Hindi',
#     'iso_639_1': 'hi',
#     'name': 'हिन्दी'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Fighter',
#   'video': False,
#   'vote_average': 5.302,
#   'vote_count': 58},
#  {'adult': False,
#   'backdrop_path': '/2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg',
#   'belongs_to_collection': None,
#   'budget': 72000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://www.migration.movie',
#   'id': 940551,
#   'imdb_id': 'tt6495056',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Migration',
#   'overview': 'After a migrating duck family alights on their pond with thrilling tales of far-flung places, the Mallard family embarks on a family road trip, from New England, to New York City, to tropical Jamaica.',
#   'popularity': 607.748,
#   'poster_path': '/ldfCF9RhR40mppkzmftxapaHeTo.jpg',
#   'production_companies': [{'id': 6704,
#     'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png',
#     'name': 'Illumination',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2023-12-06',
#   'revenue': 297404638,
#   'runtime': 83,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Odd ducks welcome.',
#   'title': 'Migration',
#   'video': False,
#   'vote_average': 7.49,
#   'vote_count': 1275},
#  {'adult': False,
#   'backdrop_path': '/oMiKHO3H5RixfLsiU5Vumhlp5sj.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 80, 'name': 'Crime'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://tickets.loveliesbleeding.movie',
#   'id': 948549,
#   'imdb_id': 'tt19637052',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Love Lies Bleeding',
#   'overview': 'Reclusive gym manager Lou falls hard for Jackie, an ambitious bodybuilder headed through town to Las Vegas in pursuit of her dream. But their love ignites violence, pulling them deep into the web of Lou’s criminal family.',
#   'popularity': 576.84,
#   'poster_path': '/p7jyFWiLyHPttqYBFAlLJwtYTYH.jpg',
#   'production_companies': [{'id': 6705,
#     'logo_path': '/e8EXNSfwr5E9d3TR8dHKbQnQK4W.png',
#     'name': 'Film4 Productions',
#     'origin_country': 'GB'},
#    {'id': 129195,
#     'logo_path': None,
#     'name': 'Escape Plan',
#     'origin_country': 'GB'},
#    {'id': 41077,
#     'logo_path': '/1ZXsGaFPgrgS6ZZGS37AqD5uU12.png',
#     'name': 'A24',
#     'origin_country': 'US'},
#    {'id': 173376,
#     'logo_path': None,
#     'name': 'Lobo Films',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2024-03-08',
#   'revenue': 8770948,
#   'runtime': 104,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Revenge gets ripped.',
#   'title': 'Love Lies Bleeding',
#   'video': False,
#   'vote_average': 6.833,
#   'vote_count': 123},
#  {'adult': False,
#   'backdrop_path': '/7ZP8HtgOIDaBs12krXgUIygqEsy.jpg',
#   'belongs_to_collection': {'id': 1000386,
#    'name': 'Alienoid Collection',
#    'poster_path': '/uXA8RfOBaKWmGUn6J5BOFdKh6b8.jpg',
#    'backdrop_path': '/tySCSCVveLrYl4RpTQIQXMMYcF6.jpg'},
#   'budget': 24500000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 601796,
#   'imdb_id': 'tt20168564',
#   'origin_country': ['KR'],
#   'original_language': 'ko',
#   'original_title': '외계+인 1부',
#   'overview': "Gurus in the late Goryeo dynasty try to obtain a fabled, holy sword, and humans in 2022 hunt down an alien prisoner that is locked in a human's body. The two parties cross paths when a time-traveling portal opens up.",
#   'popularity': 570.84,
#   'poster_path': '/8QVDXDiOGHRcAD4oM6MXjE0osSj.jpg',
#   'production_companies': [{'id': 118358,
#     'logo_path': '/57u7ny0hdDRaDdwdrNTTj9np6Cx.png',
#     'name': 'Caper Film',
#     'origin_country': 'KR'}],
#   'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   'release_date': '2022-07-20',
#   'revenue': 12600000,
#   'runtime': 142,
#   'spoken_languages': [{'english_name': 'Korean',
#     'iso_639_1': 'ko',
#     'name': '한국어/조선말'}],
#   'status': 'Released',
#   'tagline': 'For ages, aliens have locked up their prisoners in humans bodies.',
#   'title': 'Alienoid',
#   'video': False,
#   'vote_average': 6.798,
#   'vote_count': 307},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}],
#   'homepage': '',
#   'id': 865921,
#   'imdb_id': None,
#   'origin_country': ['CN'],
#   'original_language': 'zh',
#   'original_title': '特种兵归来之绝地营救',
#   'overview': 'After Long Wei and his men finished their operation in Fuji, they received a distress message from his ex-wife, Leng Yun. Long Wei immediately rushes to Southeast Asia alone to look for his ex-wife. With his excellent ability to fight alone, Long Wei and his daughter break through all the dangers they encounter one by one, will they be able to rescue his ex-wife successfully?',
#   'popularity': 546.09,
#   'poster_path': '/i28T4z3JxRf6xwuunXAedTxkNDX.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2021-07-10',
#   'revenue': 0,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'Mandarin',
#     'iso_639_1': 'zh',
#     'name': '普通话'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Return of Special Forces 5',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg',
#   'belongs_to_collection': None,
#   'budget': 50000000,
#   'genres': [{'id': 10752, 'name': 'War'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://a24films.com/films/civil-war',
#   'id': 929590,
#   'imdb_id': 'tt17279496',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'Civil War',
#   'overview': 'In the near future, a group of war journalists attempt to survive while reporting the truth as the United States stands on the brink of civil war.',
#   'popularity': 541.412,
#   'poster_path': '/sh7Rg8Er3tFcN9BpKIPOMvALgZd.jpg',
#   'production_companies': [{'id': 284,
#     'logo_path': '/6a26if3IKy7mlrQuGHHVp6ufQtF.png',
#     'name': 'DNA Films',
#     'origin_country': 'GB'},
#    {'id': 142269,
#     'logo_path': '/ggrWFqk5mPMks0vE3aCy3l9e0dv.png',
#     'name': 'IPR.VC',
#     'origin_country': 'FI'}],
#   'production_countries': [{'iso_3166_1': 'FI', 'name': 'Finland'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2024-04-10',
#   'revenue': 72245095,
#   'runtime': 109,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Welcome to the frontline.',
#   'title': 'Civil War',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 567},
#  {'adult': False,
#   'backdrop_path': '/tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg',
#   'belongs_to_collection': {'id': 1178688,
#    'name': 'Justice League (Tomorrowverse) Collection',
#    'poster_path': '/wqU63rtzsgw1wfZ4BJcReEDP54n.jpg',
#    'backdrop_path': None},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.warnerbros.com/movies/justice-league-crisis-infinite-earths-part-two',
#   'id': 1209288,
#   'imdb_id': 'tt30150907',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Justice League: Crisis on Infinite Earths Part Two',
#   'overview': 'An endless army of shadow demons bent on the destruction of all reality swarms over our world and all parallel Earths! The only thing opposing them is the mightiest team of metahumans ever assembled. But not even the combined power of Superman, Batman, Wonder Woman, Green Lantern and all their fellow superheroes can slow down the onslaught of this invincible horde. What mysterious force is driving them? And how do the long-buried secrets of the Monitor and Supergirl threaten to crush our last defense?',
#   'popularity': 534.998,
#   'poster_path': '/g8ak4QAGLZpqMs3CpnFHWWfIzJQ.jpg',
#   'production_companies': [{'id': 2785,
#     'logo_path': '/l5zW8jjmQOCx2dFmvnmbYmqoBmL.png',
#     'name': 'Warner Bros. Animation',
#     'origin_country': 'US'},
#    {'id': 9993,
#     'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png',
#     'name': 'DC Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-04-22',
#   'revenue': 0,
#   'runtime': 94,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Justice League: Crisis on Infinite Earths Part Two',
#   'video': False,
#   'vote_average': 6.396,
#   'vote_count': 53},
#  {'adult': False,
#   'backdrop_path': '/lzWHmYdfeFiMIY4JaMmtR7GEli3.jpg',
#   'belongs_to_collection': {'id': 726871,
#    'name': 'Dune Collection',
#    'poster_path': '/wcVafar6Efk3YgFvh8oZQ4yHL6H.jpg',
#    'backdrop_path': '/ygVSGv86R0BTOKJIb8RQ1sFxs4q.jpg'},
#   'budget': 165000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.dunemovie.com/',
#   'id': 438631,
#   'imdb_id': 'tt1160419',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Dune',
#   'overview': "Paul Atreides, a brilliant and gifted young man born into a great destiny beyond his understanding, must travel to the most dangerous planet in the universe to ensure the future of his family and his people. As malevolent forces explode into conflict over the planet's exclusive supply of the most precious resource in existence-a commodity capable of unlocking humanity's greatest potential-only those who can conquer their fear will survive.",
#   'popularity': 533.044,
#   'poster_path': '/d5NXSklXo0qyIYkgV94XAgMIckC.jpg',
#   'production_companies': [{'id': 923,
#     'logo_path': '/8M99Dkt23MjQMTTWukq4m5XsEuo.png',
#     'name': 'Legendary Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2021-09-15',
#   'revenue': 407573628,
#   'runtime': 155,
#   'spoken_languages': [{'english_name': 'Mandarin',
#     'iso_639_1': 'zh',
#     'name': '普通话'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It begins.',
#   'title': 'Dune',
#   'video': False,
#   'vote_average': 7.784,
#   'vote_count': 11490},
#  {'adult': False,
#   'backdrop_path': '/4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg',
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/rKKSOVv6iU3nULrKQmd9uEx9gez.jpg',
#    'backdrop_path': '/56h4DCt0ogIRI7B71xD5iA5hES1.jpg'},
#   'budget': 340000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://fastxmovie.com',
#   'id': 385687,
#   'imdb_id': 'tt5433140',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Fast X',
#   'overview': "Over many missions and against impossible odds, Dom Toretto and his family have outsmarted, out-nerved and outdriven every foe in their path. Now, they confront the most lethal opponent they've ever faced: A terrifying threat emerging from the shadows of the past who's fueled by blood revenge, and who is determined to shatter this family and destroy everything—and everyone—that Dom loves, forever.",
#   'popularity': 523.543,
#   'poster_path': '/fiVW06jE7z9YnO4trhaMEdclSiC.jpg',
#   'production_companies': [{'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'},
#    {'id': 1225,
#     'logo_path': '/rIxhJMR7oK8b2fMakmTfRLY2TZv.png',
#     'name': 'One Race',
#     'origin_country': 'US'},
#    {'id': 34530,
#     'logo_path': None,
#     'name': 'Perfect Storm Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2023-05-17',
#   'revenue': 704709660,
#   'runtime': 142,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The end of the road begins.',
#   'title': 'Fast X',
#   'video': False,
#   'vote_average': 7.127,
#   'vote_count': 5115},
#  {'adult': False,
#   'backdrop_path': '/9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.capstonepictures.com/breathe',
#   'id': 720321,
#   'imdb_id': 'tt11540468',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Breathe',
#   'overview': 'Air-supply is scarce in the near future, forcing a mother and daughter to fight for survival when two strangers arrive desperate for an oxygenated haven.',
#   'popularity': 516.124,
#   'poster_path': '/wTW2t8ocWDlHns8I7vQxuqkyK58.jpg',
#   'production_companies': [{'id': 3528,
#     'logo_path': '/cCzCClIzIh81Fa79hpW5nXoUsHK.png',
#     'name': 'Thunder Road',
#     'origin_country': 'US'},
#    {'id': 179831,
#     'logo_path': '/9yUvtr26VMnSRJnePouXgOLFV7K.png',
#     'name': 'Capstone Studios',
#     'origin_country': 'US'},
#    {'id': 117761,
#     'logo_path': '/4Aa24Ase2LR6wesRolVQ0vinI8T.png',
#     'name': 'Streamline Global',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2024-04-04',
#   'revenue': 0,
#   'runtime': 93,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
# ...
#    'backdrop_path': '/bXCm94g4TXKmACRj02ZlvmKp09m.jpg'},
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 13313,
#   'imdb_id': 'tt0118692',
#   'origin_country': ['US', 'CA'],
#   'original_language': 'en',
#   'original_title': 'Beauty and the Beast: The Enchanted Christmas',
#   'overview': 'Astonished to find the Beast has a deep-seeded hatred for the Christmas season, Belle endeavors to change his mind on the matter.',
#   'popularity': 77.395,
#   'poster_path': '/qxtpbcbf6KEIHzLetWZOVGJT2lv.jpg',
#   'production_companies': [{'id': 3475,
#     'logo_path': '/jTPNzDEn7eHmp3nEXEEtkHm6jLg.png',
#     'name': 'Disney Television Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '1997-11-11',
#   'revenue': 0,
#   'runtime': 72,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "All the magic of Disney's legendary classic continues.",
#   'title': 'Beauty and the Beast: The Enchanted Christmas',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 972},
#  {'adult': False,
#   'backdrop_path': '/cbdW4WjsY7jUZXdGB057o1Aasld.jpg',
#   'belongs_to_collection': {'id': 1214316,
#    'name': 'One Shot Collection',
#    'poster_path': '/63Akejo2rXNZNAXc7XgOVeot4Ip.jpg',
#    'backdrop_path': '/zwipmy4m0iAA8IpqcID95MsaNsd.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}],
#   'homepage': '',
#   'id': 1214314,
#   'imdb_id': 'tt27110516',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'One More Shot',
#   'overview': 'Following the attack on the black site in Poland, Navy SEAL Jake Harris is ordered to escort terrorist suspect Amin Mansur to Washington D.C. for interrogation. Before the prisoner transfer process is complete, though, the airport is attacked by a group of heavily armed, well-trained mercenaries.',
#   'popularity': 79.802,
#   'poster_path': '/4XxnWZzhMC1rOzUCJpc6CzmBIQe.jpg',
#   'production_companies': [{'id': 206783,
#     'logo_path': '/mVo5Ir4gatRa1U94v4p9Mr15OPJ.png',
#     'name': 'Signature Films',
#     'origin_country': 'US'},
#    {'id': 9987,
#     'logo_path': '/o5OTKAw7Acl5fTZYPyl8M8D9570.png',
#     'name': 'Lipsync Productions',
#     'origin_country': 'GB'},
#    {'id': 217564,
#     'logo_path': '/7Yb6Q3ClXJfBym8qwVo9BC1Xr7y.png',
#     'name': 'Sky Cinema',
#     'origin_country': 'GB'},
#    {'id': 215964,
#     'logo_path': '/hgueKTQkSwc6r7rNfMaC155E1bl.png',
#     'name': 'Richmond Pictures',
#     'origin_country': 'GB'},
#    {'id': 114874,
#     'logo_path': '/lfk5FKLlTBaWqYHLeJs7J9atmNr.png',
#     'name': 'Signature Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2024-01-09',
#   'revenue': 0,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'One More Shot',
#   'video': False,
#   'vote_average': 6.595,
#   'vote_count': 184},
#  {'adult': False,
#   'backdrop_path': '/ih4lZkUpmSE7AP3maymiO72xJ1z.jpg',
#   'belongs_to_collection': {'id': 87359,
#    'name': 'Mission: Impossible Collection',
#    'poster_path': '/geEjCGfdmRAA1skBPwojcdvnZ8A.jpg',
#    'backdrop_path': '/jYl0UuJFcmhymv9ZNO14lPLDY1Z.jpg'},
#   'budget': 145000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 56292,
#   'imdb_id': 'tt1229238',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Mission: Impossible - Ghost Protocol',
#   'overview': 'Ethan Hunt and his team are racing against time to track down a dangerous terrorist named Hendricks, who has gained access to Russian nuclear launch codes and is planning a strike on the United States. An attempt to stop him ends in an explosion causing severe destruction to the Kremlin and the IMF to be implicated in the bombing, forcing the President to disavow them. No longer being aided by the government, Ethan and his team chase Hendricks around the globe, although they might still be too late to stop a disaster.',
#   'popularity': 80.383,
#   'poster_path': '/7GCKNRbzcA4rJXAKoE8KS9IDnZP.jpg',
#   'production_companies': [{'id': 4,
#     'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#     'name': 'Paramount',
#     'origin_country': 'US'},
#    {'id': 11461,
#     'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#     'name': 'Bad Robot',
#     'origin_country': 'US'},
#    {'id': 21777,
#     'logo_path': None,
#     'name': 'TC Productions',
#     'origin_country': 'US'},
#    {'id': 82819,
#     'logo_path': '/gXfFl9pRPaoaq14jybEn1pHeldr.png',
#     'name': 'Skydance Media',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2011-12-07',
#   'revenue': 694700000,
#   'runtime': 133,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'Arabic', 'iso_639_1': 'ar', 'name': 'العربية'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'}],
#   'status': 'Released',
#   'tagline': 'No plan. No backup. No choice.',
#   'title': 'Mission: Impossible - Ghost Protocol',
#   'video': False,
#   'vote_average': 7.079,
#   'vote_count': 9579},
#  {'adult': False,
#   'backdrop_path': '/nLitXHcOD2jxwE6rq6sTi4ZMmo5.jpg',
#   'belongs_to_collection': {'id': 945984,
#    'name': 'I Am Legend Collection',
#    'poster_path': '/kMWArwXFzMwCzRMRzJqZBC6d22A.jpg',
#    'backdrop_path': '/nvwI0ohPlC4M9rBMr3ZORFvcMQr.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'http://iamlegend.warnerbros.com',
#   'id': 6479,
#   'imdb_id': 'tt0480249',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'I Am Legend',
#   'overview': 'Robert Neville is a scientist who was unable to stop the spread of the terrible virus that was incurable and man-made. Immune, Neville is now the last human survivor in what is left of New York City and perhaps the world. For three years, Neville has faithfully sent out daily radio messages, desperate to find any other survivors who might be out there. But he is not alone.',
#   'popularity': 92.12,
#   'poster_path': '/iPDkaSdKk2jRLTM65UOEoKtsIZ8.jpg',
#   'production_companies': [{'id': 174,
#     'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'},
#    {'id': 79,
#     'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png',
#     'name': 'Village Roadshow Pictures',
#     'origin_country': 'US'},
#    {'id': 433,
#     'logo_path': '/iafkKMpcRfEXq9a4sQf0h6tg2E2.png',
#     'name': 'Weed Road Pictures',
#     'origin_country': 'US'},
#    {'id': 907,
#     'logo_path': '/ca5SWI5uvU985f8Kbb4xc8AmVWH.png',
#     'name': 'Overbrook Entertainment',
#     'origin_country': 'US'},
#    {'id': 437,
#     'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png',
#     'name': 'Heyday Films',
#     'origin_country': 'GB'},
#    {'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2007-12-12',
#   'revenue': 585410052,
#   'runtime': 101,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The last man on Earth is not alone',
#   'title': 'I Am Legend',
#   'video': False,
#   'vote_average': 7.204,
#   'vote_count': 15242},
#  {'adult': False,
#   'backdrop_path': '/sDAavcrOSbFnFt4zpjNqzaoNr3w.jpg',
#   'belongs_to_collection': {'id': 33514,
#    'name': 'The Twilight Collection',
#    'poster_path': '/aKAX2HO5V94JYeSIkOMFNlRI71E.jpg',
#    'backdrop_path': '/3be0BffeZTyMbj4Ndzo6Y877SBQ.jpg'},
#   'budget': 50000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 18239,
#   'imdb_id': 'tt1259571',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Twilight Saga: New Moon',
#   'overview': "Forks, Washington resident Bella Swan is reeling from the departure of her vampire love, Edward Cullen, and finds comfort in her friendship with Jacob Black, a werewolf. But before she knows it, she's thrust into a centuries-old conflict, and her desire to be with Edward at any cost leads her to take greater and greater risks.",
#   'popularity': 80.851,
#   'poster_path': '/k2qTooPlHffgNABNWxeJdGMglPK.jpg',
#   'production_companies': [{'id': 491,
#     'logo_path': '/5LvDUt3KmvRnXQ4NrdWJYHeuA8J.png',
#     'name': 'Summit Entertainment',
#     'origin_country': 'US'},
#    {'id': 12292,
#     'logo_path': '/4GQTeqos2luopEtp3OgMQYusQ5c.png',
#     'name': 'Temple Hill Entertainment',
#     'origin_country': 'US'},
#    {'id': 4000,
#     'logo_path': None,
#     'name': 'Maverick Films',
#     'origin_country': 'US'},
#    {'id': 5218,
#     'logo_path': '/dhb42ugM9DzSpDctTWCtABPVOW4.png',
#     'name': 'Imprint Entertainment',
#     'origin_country': 'US'},
#    {'id': 5219,
#     'logo_path': None,
#     'name': 'Sunswept Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2009-11-18',
#   'revenue': 709827462,
#   'runtime': 131,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}],
#   'status': 'Released',
#   'tagline': 'The Next Chapter Begins.',
#   'title': 'The Twilight Saga: New Moon',
#   'video': False,
#   'vote_average': 5.992,
#   'vote_count': 8907},
#  {'adult': False,
#   'backdrop_path': '/jw88BtmMliB1Mbwf3JyfYszS4Xk.jpg',
#   'belongs_to_collection': None,
#   'budget': 72000000,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': '',
#   'id': 2675,
#   'imdb_id': 'tt0286106',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Signs',
#   'overview': 'A family living on a farm finds mysterious crop circles in their fields which suggests something more frightening to come.',
#   'popularity': 63.845,
#   'poster_path': '/hyZkNEbNgnciUVTyu4NZTjlCh4L.jpg',
#   'production_companies': [{'id': 9195,
#     'logo_path': '/ou5BUbtulr6tIt699q6xJiEQTR9.png',
#     'name': 'Touchstone Pictures',
#     'origin_country': 'US'},
#    {'id': 12236,
#     'logo_path': '/bVu0qQm4GujSTCvZZz9S3rHDczA.png',
#     'name': 'Blinding Edge Pictures',
#     'origin_country': 'US'},
#    {'id': 862,
#     'logo_path': '/udTjbqPmcTbfrihMuLtLcizDEM1.png',
#     'name': 'The Kennedy/Marshall Company',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2002-08-02',
#   'revenue': 408200000,
#   'runtime': 106,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Portuguese', 'iso_639_1': 'pt', 'name': 'Português'}],
#   'status': 'Released',
#   'tagline': "It's not like they didn't warn us.",
#   'title': 'Signs',
#   'video': False,
#   'vote_average': 6.686,
#   'vote_count': 5377},
#  {'adult': False,
#   'backdrop_path': '/u2IlqBzlGqMwDnQsoskjCohgaPO.jpg',
#   'belongs_to_collection': {'id': 2344,
#    'name': 'The Matrix Collection',
#    'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#    'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.warnerbros.com/movies/matrix-reloaded',
#   'id': 604,
#   'imdb_id': 'tt0234215',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Matrix Reloaded',
#   'overview': "Six months after the events depicted in The Matrix, Neo has proved to be a good omen for the free humans, as more and more humans are being freed from the matrix and brought to Zion, the one and only stronghold of the Resistance.  Neo himself has discovered his superpowers including super speed, ability to see the codes of the things inside the matrix and a certain degree of pre-cognition. But a nasty piece of news hits the human resistance: 250,000 machine sentinels are digging to Zion and would reach them in 72 hours. As Zion prepares for the ultimate war, Neo, Morpheus and Trinity are advised by the Oracle to find the Keymaker who would help them reach the Source.  Meanwhile Neo's recurrent dreams depicting Trinity's death have got him worried and as if it was not enough, Agent Smith has somehow escaped deletion, has become more powerful than before and has fixed Neo as his next target.",
#   'popularity': 77.845,
#   'poster_path': '/9TGHDvWrqKBzwDxDodHYXEmOE6J.jpg',
#   'production_companies': [{'id': 79,
#     'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png',
#     'name': 'Village Roadshow Pictures',
#     'origin_country': 'US'},
#    {'id': 1885,
#     'logo_path': '/xlvoOZr4s1PygosrwZyolIFe5xs.png',
#     'name': 'Silver Pictures',
#     'origin_country': 'US'},
#    {'id': 172,
#     'logo_path': None,
#     'name': 'NPV Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2003-05-15',
#   'revenue': 738599701,
#   'runtime': 138,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'Free your mind.',
#   'title': 'The Matrix Reloaded',
#   'video': False,
#   'vote_average': 7.048,
#   'vote_count': 10578},
#  {'adult': False,
#   'backdrop_path': '/wE5JGzujfvDPMIfFjJyrhXFjZLc.jpg',
#   'belongs_to_collection': {'id': 10194,
#    'name': 'Toy Story Collection',
#    'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#    'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'}],
#   'homepage': 'http://disney.go.com/toystory/',
#   'id': 10193,
#   'imdb_id': 'tt0435761',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Toy Story 3',
#   'overview': "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.",
#   'popularity': 86.076,
#   'poster_path': '/AbbXspMOwdvwWZgVN0nabZq03Ec.jpg',
#   'production_companies': [{'id': 3,
#     'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#     'name': 'Pixar',
#     'origin_country': 'US'},
#    {'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2010-06-16',
#   'revenue': 1067316101,
#   'runtime': 103,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'No toy gets left behind.',
#   'title': 'Toy Story 3',
#   'video': False,
#   'vote_average': 7.795,
#   'vote_count': 14226},
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(all_movie_details)

# columns to select
columns_to_select = ['imdb_id', 'title', 'original_language', 'origin_country', 'adult',
                     'genres', 'budget', 'revenue', 'release_date', 
                     'runtime','popularity', 'vote_average', 'vote_count']

# Selecting the columns from dataset
selected_df = df[columns_to_select]

# Renaming the columns
selected_df = selected_df.rename(columns={
    'original_language': 'language', 
    'origin_country': 'country',
    'genres': 'genres', 
    'vote_average': 'avg_rating', 
    'vote_count': 'people_rated'
})

# %%
selected_df.to_csv('api_movie_data.csv', index = False)

# %%
import boto3

def upload_file_to_s3(file_name, bucket_name, object_name=None):

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = file_name

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket_name, object_name)
    except Exception as e:
        print(f"Upload failed: {e}")
        return False
    return True

# Example usage:
file_name = 'api_movie_data.csv'
bucket_name = 'final-project-rawdata-group-5-sec-2'
upload_file_to_s3(file_name, bucket_name)
# Out:
# True
